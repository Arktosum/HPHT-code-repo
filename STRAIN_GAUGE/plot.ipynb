# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./serial_data.csv',header=None)
df.head()
# Out:
#      0    1
# 0  0.0  400
# 1  0.1  389
# 2  0.2  381
# 3  0.3  373
# 4  0.4  368

# %%
plt.plot(df[0],df[1]);
